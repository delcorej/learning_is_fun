# %% [markdown]
# <a href="https://colab.research.google.com/github/delcorej/learning_is_fun/blob/main/Sports_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing necessary libraries
import requests
import pandas as pd
import json
import time
from os import getcwd

# %%
##Endpoint url for the odds api
url = 'https://api.the-odds-api.com/v4/sports/americanfootball_nfl/odds/'

## setting desired parameters

parameters = {
    'apiKey': 'ae081625c8d7b82c42c0230cf8ca5b00',
    'regions': 'us',
    'markets': 'h2h,spreads,totals',
    'oddsFormat': 'american',
}

#Get a repsonse from the api's
response = requests.get(url,params=parameters)
data = response.json()

# %%
## local file testing
def read_json(filename: str) -> dict:
  try:
    with open(filename, "r") as f:
      data = json.loads(f.read())
  except:
    raise Exception(f"Reading {filename} file encounterred an error")
  return data

  data = read_json(filename='/content/drive/MyDrive/sports/asdf.json')

# %%
  dataframe = pd.json_normalize(data, sep= '_',
              record_path=['bookmakers', 'markets', 'outcomes'],
                meta=['id', 'sport_key', 'sport_title', 'commence_time', 'home_team', 'away_team',
                ['bookmakers', 'key'], ['bookmakers', 'title'], ['bookmakers', 'last_update'],
                      ['bookmakers', 'markets', 'key'], ['bookmakers', 'markets', 'last_update']]
  )

# %%
dataframe.to_csv()
# Out:
# ',name,price,point,id,sport_key,sport_title,commence_time,home_team,away_team,bookmakers_key,bookmakers_title,bookmakers_last_update,bookmakers_markets_key,bookmakers_markets_last_update\n0,San Francisco 49ers,630,-13.5,8dcb7c89abe06e78be444bc54284ad95,americanfootball_nfl,NFL,2023-11-19T21:06:00Z,San Francisco 49ers,Tampa Bay Buccaneers,fanduel,FanDuel,2023-11-19T23:48:28Z,spreads,2023-11-19T23:48:28Z\n1,Tampa Bay Buccaneers,-1300,13.5,8dcb7c89abe06e78be444bc54284ad95,americanfootball_nfl,NFL,2023-11-19T21:06:00Z,San Francisco 49ers,Tampa Bay Buccaneers,fanduel,FanDuel,2023-11-19T23:48:28Z,spreads,2023-11-19T23:48:28Z\n2,San Francisco 49ers,750,-13.5,8dcb7c89abe06e78be444bc54284ad95,americanfootball_nfl,NFL,2023-11-19T21:06:00Z,San Francisco 49ers,Tampa Bay Buccaneers,draftkings,DraftKings,2023-11-19T23:47:58Z,spreads,2023-11-19T23:47:58Z\n3,Tampa Bay Buccaneers,-1450,13.5,8dcb7c89abe06e78be444bc54284ad95,americanfootball_nfl,NFL,2023-11-19T21:06:00Z,San Francisco 49ers,Tampa Bay Bu
# ...

# %%
dataframe.head()
# Out:
#                    name  price  point                                id  \
# 0   San Francisco 49ers    630  -13.5  8dcb7c89abe06e78be444bc54284ad95
# 1  Tampa Bay Buccaneers  -1300   13.5  8dcb7c89abe06e78be444bc54284ad95
# 2   San Francisco 49ers    750  -13.5  8dcb7c89abe06e78be444bc54284ad95
# 3  Tampa Bay Buccaneers  -1450   13.5  8dcb7c89abe06e78be444bc54284ad95
# 4                  Over    420   41.5  8dcb7c89abe06e78be444bc54284ad95
#
#               sport_key sport_title         commence_time  \
# 0  americanfootball_nfl         NFL  2023-11-19T21:06:00Z
# 1  americanfootball_nfl         NFL  2023-11-19T21:06:00Z
# 2  americanfootball_nfl         NFL  2023-11-19T21:06:00Z
# 3  americanfootball_nfl         NFL  2023-11-19T21:06:00Z
# 4  americanfootball_nfl         NFL  2023-11-19T21:06:00Z
#
#              home_team             away_team bookmakers_key bookmakers_title  \
# 0  San Francisco 49ers  Tampa Bay Buccaneers        fanduel          FanDuel
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            504 non-null    object
#  1   price                           504 non-null    int64
#  2   point                           356 non-null    float64
#  3   id                              504 non-null    object
#  4   sport_key                       504 non-null    object
#  5   sport_title                     504 non-null    object
#  6   commence_time                   504 non-null    object
#  7   home_team                       504 non-null    object
#  8   away_team                       504 non-null    object
#  9   bookmakers_key                  504 non-null    object
#  10  bookmakers_title                504 non-null    object
#  11  bookmakers_last_update          504 non-null    object
# ...

# %%
dataframe[dataframe['price']<0].sort_values(by='price',ascending=True)
# Out:
#                     name   price  point                                id  \
# 20   San Francisco 49ers -200000    NaN  8dcb7c89abe06e78be444bc54284ad95
# 50         Buffalo Bills -142858    NaN  7ffa1ceb2b78914d13f2e894ed2e83bd
# 32         Buffalo Bills -100000    NaN  7ffa1ceb2b78914d13f2e894ed2e83bd
# 56         Buffalo Bills  -10000    NaN  7ffa1ceb2b78914d13f2e894ed2e83bd
# 22   San Francisco 49ers  -10000  -12.5  8dcb7c89abe06e78be444bc54284ad95
# ..                   ...     ...    ...                               ...
# 358      Atlanta Falcons    -102   -1.5  4a12e8418289ef8d56250b020a9b5c15
# 308        Detroit Lions    -102   -7.0  0f2909e25d9307a32b840dcccf848e5f
# 121    Minnesota Vikings    -102    2.5  d59ec10420e78737c5fdfb5371c4c8e0
# 235  Philadelphia Eagles    -102    2.5  7ada5a3ce1269f9c0953a196b5fb4a0c
# 139    Minnesota Vikings    -101    2.5  d59ec10420e78737c5fdfb5371c4c8e0
#
#                 sport_key sport_title         commence_time  \
# ...

# %%
dataframe[dataframe['point']<0].sort_values(by='point',ascending=True)
# Out:
#                     name  price  point                                id  \
# 40         Buffalo Bills   -122  -25.5  7ffa1ceb2b78914d13f2e894ed2e83bd
# 58         Buffalo Bills   -125  -25.5  7ffa1ceb2b78914d13f2e894ed2e83bd
# 36         Buffalo Bills   -122  -25.5  7ffa1ceb2b78914d13f2e894ed2e83bd
# 28         Buffalo Bills   -125  -25.5  7ffa1ceb2b78914d13f2e894ed2e83bd
# 52         Buffalo Bills   -112  -24.0  7ffa1ceb2b78914d13f2e894ed2e83bd
# ..                   ...    ...    ...                               ...
# 399  Pittsburgh Steelers   -110   -1.0  4fc56a4d2185021682448f394e367742
# 368      Atlanta Falcons   -110   -1.0  4a12e8418289ef8d56250b020a9b5c15
# 365   New Orleans Saints   -105   -1.0  4a12e8418289ef8d56250b020a9b5c15
# 437       Denver Broncos   -110   -1.0  f1788bb541815fe2a101212cf18d5af9
# 426   Indianapolis Colts   -110   -1.0  a721e155795f890bffe4c51c3dc0a472
#
#                 sport_key sport_title         commence_time  \
# ...

# %%
dataframe.groupby(['point','name'])['price'].describe()
# Out:
#                            count        mean        std    min    25%    50%  \
# point name
# -25.5 Buffalo Bills          4.0 -123.500000   1.732051 -125.0 -125.0 -123.5
# -24.0 Buffalo Bills          1.0 -112.000000        NaN -112.0 -112.0 -112.0
# -23.5 Buffalo Bills          3.0 -114.333333   9.291573 -125.0 -117.5 -110.0
# -13.5 San Francisco 49ers    2.0  690.000000  84.852814  630.0  660.0  690.0
# -13.0 San Francisco 49ers    1.0 -320.000000        NaN -320.0 -320.0 -320.0
# ...                          ...         ...        ...    ...    ...    ...
#  47.5 Under                  7.0 -109.857143   5.928141 -120.0 -112.5 -110.0
#  48.0 Over                   1.0 -115.000000        NaN -115.0 -115.0 -115.0
#       Under                  1.0 -115.000000        NaN -115.0 -115.0 -115.0
#  48.5 Over                   1.0  150.000000        NaN  150.0  150.0  150.0
#       Under                  1.0 -200.000000        NaN -200.0 -200.0 -200.0
#
# ...

# %%
dataframe.sample(14)
# Out:
#                      name  price  point                                id  \
# 261                 Under   -110   45.5  7ada5a3ce1269f9c0953a196b5fb4a0c
# 337                 Under   -110   46.0  a6e073fff37db15464e7e44b71462a20
# 476      Baltimore Ravens   -110   -4.0  eb77c9dad13ef82ba5ff4dcf439d3bab
# 2     San Francisco 49ers    750  -13.5  8dcb7c89abe06e78be444bc54284ad95
# 483  Los Angeles Chargers   -110    4.5  eb77c9dad13ef82ba5ff4dcf439d3bab
# 90       Los Angeles Rams    400    NaN  bc7543ec7bf3dddcc6d71b433ef360d0
# 49                  Under   -115   48.0  7ffa1ceb2b78914d13f2e894ed2e83bd
# 250    Kansas City Chiefs   -148    NaN  7ada5a3ce1269f9c0953a196b5fb4a0c
# 191     Minnesota Vikings    120    NaN  d59ec10420e78737c5fdfb5371c4c8e0
# 45          New York Jets   1100    NaN  7ffa1ceb2b78914d13f2e894ed2e83bd
# 354                  Over   -110   42.0  32c414934534235b0885860a21180ddc
# 44          Buffalo Bills  -2800    NaN  7ffa1ceb2b78914d13f2e894ed2e83bd
# ...

# %%
## importing data exploratory libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#scikit - learn
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from sklearn import tree

# %%
# ## checking if the reponse was successful
# if response.status_code == 200:

#   events = data
#   # normalizing the data utilizing pandas

#   dataframe = pd.json_normalize(data, sep= '_',
#               record_path=['bookmakers', 'markets', 'outcomes'],
#                 meta=['id', 'sport_key', 'sport_title', 'commence_time', 'home_team', 'away_team',
#                 ['bookmakers', 'key'], ['bookmakers', 'title'], ['bookmakers', 'last_update'],
#                       ['bookmakers', 'markets', 'key'], ['bookmakers', 'markets', 'last_update']]
#   )
#     ## exporting the data to a csv
#   datestr = time.strftime("%Y%m%d")
#   dir = getcwd() + '/dyno_values/data/'

#   filename = dir + 'nfl_odds' + datestr + '.csv'
#   dataframe.to_csv(filename, index=False)

#   print(f"Data exported sucessfully to {filename}!")

#     # checking the api usuage
#   print('Remaining requests', response.headers['x-requests-remaing'])
#   print('Used requests', response.headers['x-requests-used'])

# else:
#   print("Failed to retrieve data from the API.")
